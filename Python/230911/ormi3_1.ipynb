# %% [markdown]
# # 주석

# %%
# 이것은 주석입니다.
print('Hello, World1!') # 이것도 주석입니다.
print('Hello, World2!')
# Out:
# Hello, World1!
# Hello, World1!

# %%
'''
이것은 주석입니다.
이렇게 여러줄 주석을 넣을 수 있습니다.
'''
print("Hello. World!")
# Out:
# Hello. World!

# %%
"""
이것은 주석입니다.
이렇게 여러줄 주석을 넣을 수 있습니다.
"""
print("Hello. World!")
# Out:
# Hello. World!

# %% [markdown]
# # 입력과 출력

# %%
x = input('입력해 주세요:') #문자열로 받는다.
x + x
# Out:
# 입력해 주세요:10
# '1010'

# %%
print('hello world')
# Out:
# hello world

# %%
x = 'hello'
print(x)
# Out:
# hello

# %%
print(x, x)
# Out:
# hello hello

# %%
print(x, x, sep='-')
# Out:
# hello-hello

# %%
print('010', '0000', '0000', end='!')
print('hello world', end='~')
# Out:
# 010 0000 0000!hello world~

# %% [markdown]
# # 변수
# * python에서 변수는 포스트잇이다. 값을 담는 것이 아니라 가리킨다!

# %%
x = 10
y = x
z = y

# %%
y = 20
print(x)
# Out:
# 10

# %%
x = 2000000000000000000
y = x
z = y

# %%
print(id(x), id(y), id(z))
# Out:
# 138909230936352 138909230936352 138909230936352

# %%
# 변수 이름
# python의 경우 보통 스네이크 표기법으로 변수를 만듭니다.
col_sum = 10
# _는 사용하지 않는 변수에 할당
for _ in range(5): # _는 코드의 가독성을 높임
    print('hello'); # _가 for문 안에서 사용이 안된다.
# Out:
# hello
# hello
# hello
# hello
# hello

# %%
# π도 변수명으로 사용할 수 있지만 사회생활이 힘듬
π = 100
π + π
# Out:
# 200

# %%
# 변수 타입: 변수들을 어떻게 관리하고 처리할지를 결정

x = 10
x + x
# Out:
# 20

# %%
y = '10'
y + y
# Out:
# '1010'

# %%
type(x)
# Out:
# int

# %%
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
int('10') + int('10')
# Out:
# 20

# %%
class str(str):
    def __add__(self, other):
        return 'hello'

# %%
str(10) + str(10)
# Out:
# 'hello'

# %%
class str(str):
    def __add__(self, other):
        return self + other

# %%
str(10) + '10'
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-3-975104b752f6> in <cell line: 1>()
# ----> 1 str(10) + '10'
#
# <ipython-input-1-9005b6909c35> in __add__(self, other)
#       1 class str(str):
#       2     def __add__(self, other):
# ----> 3         return self + other
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-1-9005b6909c35> in __add__(self, other)
#       1 class str(str):
#       2     def __add__(self, other):
# ----> 3         return self + other
#
# RecursionError: maximum recursion depth exceeded

# %%
# 변수의 삭제
del x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-338c5c114974> in <cell line: 2>()
#       1 # 변수의 삭제
# ----> 2 del x
#
# NameError: name 'x' is not defined

# %% [markdown]
# # 정수 자료형 (int)

# %%
x = 10
y = -5
z = 0
print(type(x), type(y), type(z))
# Out:
# <class 'int'> <class 'int'> <class 'int'>

# %%
x = 10
result = x * 3
result
# Out:
# 30

# %%
# 2진수
x = 0b110
print(x)
print(type(x))
# Out:
# 6
# <class 'int'>

# %%
x = 0o110
print(x)
print(type(x))
# Out:
# 72
# <class 'int'>

# %%
int(bin(15), 2)
# Out:
# 15

# %%
oct(15)
# Out:
# '0o17'

# %%
hex(15)
# Out:
# '0xf'

# %%
# 매우 중요한 내용, 새로운 자료형을 만났을 때 2개를 꼭 해봐야 한다.
x = 10
print(type(x))
print(dir(x))
# Out:
# <class 'int'>
# ['__abs__', '__add__', '__and__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getnewargs__', '__gt__', '__hash__', '__index__', '__init__', '__init_subclass__', '__int__', '__invert__', '__le__', '__lshift__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rlshift__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rrshift__', '__rshift__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', '__xor__', 'as_integer_ratio', 'bit_count', 'bit_length', 'conjugate', 'denominator', 'from_bytes', 'imag', 'numerator', 'real', 'to_bytes']

# %%
# 매직 메서드
abs(x) # __abs__
x + x # __add__
5 and 5 # __and__
bool(x) # __bool__
5 == 5 # __eq__

# 메서드: 이 타입에서 변수를 다룰 수 있는 여러 기능을 제공
# 'as_integer_ratio',
# 'bit_count',
# 'bit_length',
# 'conjugate',
# 'denominator',
# 'from_bytes',
# 'imag',
# 'numerator',
# 'real',
# 'to_bytes'
# Out:
# True

# %%
x = 5
x.bit_count() # 이걸 사용할 일은 평생에 한 번도 없을 수도 있다.
# Out:
# 2

# %%
# 정수의 메모리 미리 적재
# -5 ~ 256
x = 256
y = 256
print(id(x), id(y))
# Out:
# 135892766122192 135892766122192

# %%
x = 257
y = 257
print(id(x), id(y))
# Out:
# 135891496726928 135891496726256

# %%
x = 258
y = 258
z = x
print(id(x), id(y), id(z))
# Out:
# 135891496725456 135891496726000 135891496725456

# %% [markdown]
# # 실수 자료형 (float)

# %%
# 산술연산
x = 10.0
y = 2
result = x / y
print(result)
print(type(result))
# Out:
# 5.0
# <class 'float'>

# %%
# float의 특수값
# 이 특수값은 사용하니 기억 필요
# 주로 정렬과 같은 파트에서 초깃값으로 사용을 함
float("inf") > 100000000000000000000000
float("-inf") < -1000000000000000000000000
# Out:
# True

# %%
# 부동소숫점 문제
0.1 + 0.2
# 왜 발생하는가?
# 컴퓨터 연산은 10진수가 아니라 2진수로 연산하는데 2진수 변환에서 무한 수가 발생된다.
# Out:
# 0.30000000000000004

# %%
import decimal

# 각각 모듈 import해서 사용해야 함
float(decimal.Decimal('.1') + decimal.Decimal('.2'))
# float(fractions.Fraction('0.1') + fractions.Fraction('0.2'))
# Out:
# 0.3

# %%
x = 10.0
print(type(x), dir(x))
# Out:
# <class 'float'> ['__abs__', '__add__', '__bool__', '__ceil__', '__class__', '__delattr__', '__dir__', '__divmod__', '__doc__', '__eq__', '__float__', '__floor__', '__floordiv__', '__format__', '__ge__', '__getattribute__', '__getformat__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__int__', '__le__', '__lt__', '__mod__', '__mul__', '__ne__', '__neg__', '__new__', '__pos__', '__pow__', '__radd__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmod__', '__rmul__', '__round__', '__rpow__', '__rsub__', '__rtruediv__', '__setattr__', '__setformat__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__trunc__', 'as_integer_ratio', 'conjugate', 'fromhex', 'hex', 'imag', 'is_integer', 'real']

# %%
# float 메서드
# 'as_integer_ratio'
# 'conjugate'
# 'fromhex'
# 'hex'
# 'imag'
# 'is_integer'
# 'real'

# %% [markdown]
# # 복소수 자료형 (complex)

# %%
x = 3 + 4j
x
# Out:
# (3+4j)

# %%
type(x), dir(x)

# %%
# 'conjugate'
# 'imag'
# 'real'

# %%
x.real, x.imag
# Out:
# (3.0, 4.0)

# %% [markdown]
# # 문자열 자료형 (str)

# %%
x = 'hello world'
y = "hello world"
z = '''hello world''' # 여러줄 가능
k = """hello world""" # 여러줄 가능

# %%
# 회사마다 컨벤션이 다름
print("""hello\nhello""")
# Out:
# hello
# hello

# %%
print('''hello\nhello''')
# Out:
# hello
# hello

# %%
i = '''
안녕하세요.
황병헌입니다.
python 참 좋네요
'''

# %%
i
# Out:
# '\n안녕하세요.\n황병헌입니다.\npython 참 좋네요\n'

# %%
print(i)
# Out:
# 안녕하세요.
# 황병헌입니다.
# python 참 좋네요

# %%
x = 'hello'
y = 'world'
print(x + y)
# Out:
# helloworld

# %%
x = 'hello'
print(x * 3)
# Out:
# hellohellohello

# %%
# 이런 연산들은 문자열에서는 문제가 없지만
# 다른 자료형들은 아래와 같은 문제가 생김
x = [[100] * 3, [10] * 2]
x
# Out:
# [[100, 100, 100], [10, 10]]

# %%
x[0][0] = 1
x
# Out:
# [[1, 100, 100], [10, 10]]

# %%
x = [[[] * 2] * 3] * 2
x[0][0] = 10
x
# Out:
# [[10, [], []], [10, [], []]]

# %% [markdown]
# ## 문자열 인덱싱

# %%
s = 'hello world'
s[0]
# Out:
# 'h'

# %%
s[-1]
# Out:
# 'd'

# %%
s[-10]
# Out:
# 'e'

# %%
# 이거 중요!
# 양수와 음수로는 한 번만 갈 수 있음.
s[-12]
s[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-73-8d093900ca14> in <cell line: 1>()
# ----> 1 s[-12]
#
# IndexError: string index out of range

# %%
x = 256
y = 256

print(id(x), id(y))
# Out:
# 135892766122192 135892766122192

# %%
s = 'ormi third hwangbyeongheon'
# s[start:stop:step]
# :step은 통으로 생략 가능
# start와 stop은 숫자만 생략 가능
# 중요! slicing은 error를 발생시키지 않음

# %%
s[0:5]
s[5:0]
s[:5]
s[6:]
s[:5:2] # 2칸씩 건너띄는 코드는 거의 사용하지 않고, 알고리즘 문제에서 많이 사용
# step 값으로는 -1을 많이 사용
s[::-1]
s[5:0:-1]
# Out:
# 't imr'

# %%
s = 'ormi third hwangbyeongheon.png'
# 자주쓰지만 헷갈리는 것
s[:-4]
s[-4:]

# 슬라이싱에서 알아둬야 할 점
# 슬라이싱이 C구현체로 되어 있어 메서드보다 통상 8배 정도 빠릅니다.
# 슬라이싱으로 copy한 객체는 얕은 복사가 됩니다.
# Out:
# '.png'

# %%
x = [10, 20, 30]
y = x
print(id(x), id(y))

x = [20, 30, 40]
y = x[:]
print(id(x), id(y))
# Out:
# 132205234654848 132205234654848
# 132205235080000 132205234306560

# %% [markdown]
# ## 문자열 메서드

# %%
s = 'ormi third hwangbyeongheon'
s.lower() # 전체를 소문자로 바꾸는 메서드
s.upper() # 전체를 대문자로 바꾸는 메서드
# Out:
# (str,
#  ['__add__',
#   '__class__',
#   '__contains__',
#   '__delattr__',
#   '__dir__',
#   '__doc__',
#   '__eq__',
#   '__format__',
#   '__ge__',
#   '__getattribute__',
#   '__getitem__',
#   '__getnewargs__',
#   '__gt__',
#   '__hash__',
#   '__init__',
#   '__init_subclass__',
#   '__iter__',
#   '__le__',
#   '__len__',
#   '__lt__',
#   '__mod__',
#   '__mul__',
#   '__ne__',
#   '__new__',
#   '__reduce__',
#   '__reduce_ex__',
#   '__repr__',
#   '__rmod__',
#   '__rmul__',
#   '__setattr__',
#   '__sizeof__',
#   '__str__',
#   '__subclasshook__',
#   'capitalize',
#   'casefold',
#   'center',
#   'count',
#   'encode',
#   'endswith',
#   'expandtabs',
#   'find',
#   'format',
#   'format_map',
#   'index',
#   'isalnum',
#   'isalpha',
#   'isascii',
#   'isdecimal',
#   'isdigit',
#   'isidentifier',
#   'islower',
#   'isnumeric',
#   'isprintable',
#   'isspace',
#   'istitle',
#   'isupper',
#   'join',
#   'ljust',
#   'lower',
#   'lstrip',
#   'maketrans',
# ...

# %%
s = 'ormi third hwangbyeongheon'
s.find('two'), s.index('two')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-e037b7affdfc> in <cell line: 2>()
#       1 s = 'ormi third hwangbyeongheon'
# ----> 2 s.find('two'), s.index('two')
#
# ValueError: substring not found

# %%
s = 'ormi third hwangbyeongheon'
bool(s.find('two'))

# 에러가 나지 않는 코드가 좋은 코드일까?
# 에러가 적절한 곳에서 나고, 예외처리가 견고히 된 코드가 좋은 코드
# Out:
# True

# %%
s = 'ormi third hwangbyeongheon'
s.count('i')
# Out:
# 2

# %%
s = '            ormi third hwangbyeongheon       '
s.strip() # 양쪽 공백을 제거하는 메소드
# Out:
# 'ormi third hwangbyeongheon'

# %%
'    ,!!  hello world   '.strip(' ,!')
#양쪽의 공백과 ',!'을 제거해주는 method
# Out:
# 'hello world'

# %%
s = 'ormi third hwangbyeongheon'
s.replace('third', 'second')
# Out:
# 'ormi second hwangbyeongheon'

# %%
s = 'ormi third hwangbyeongheon'
''.join(s.split(' '))
# Out:
# 'ormithirdhwangbyeongheon'

# %%
name = 'hwangbyeongheon'
age = 30

print('제 이름은 %s 제 나이는 %d' % (name, age))
print('제 이름은', name, '제 나이는', age)
print('제 이름은 {} 제 나이는 {}'.format(name, age))
print(f'제 이름은 {name} 제 나이는 {age}') # 이 방식 사용을 권고
# Out:
# 제 이름은 hwangbyeongheon 제 나이는 30
# 제 이름은 hwangbyeongheon 제 나이는 30
# 제 이름은 hwangbyeongheon 제 나이는 30
# 제 이름은 hwangbyeongheon 제 나이는 30

# %%
'abcd1234'.isalnum()
'안녕'.isalnum()
'hello'.isascii()
# Out:
# True

# %%
'hello'.isdigit()
'안녕'.isdigit()
'123'.isdigit()
'12.3'.isdigit() # 점을 찍으면 문자라고 인식함.
'10e10'.isdigit() # 지수 표현 인식 못함
# Out:
# False

# %%
'hello world'.isalpha()
'helloworld'.isalpha()
# Out:
# True

# %%
s = 'byeong'
s.center(13, '-')
# Out:
# '----byeong---'

# %%
x = "42"
result = x.zfill(5)
print(result)  # 00042
# Out:
# 00042

# %%
filename = '1'.zfill(3) + '.html'
print(filename)
# Out:
# 001.html

# %%
년 = '23'
월 = '9'
일 = '8'
오늘날짜 = f'{년.zfill(2)}/{월.zfill(2)}/{일.zfill(2)}'
print(오늘날짜)
# Out:
# 23/09/08

# %%
n = 5
arr1 = [9, 20, 28, 18, 11]
arr2 = [30, 1, 21, 17, 28]

# %%
def solution(n, arr1, arr2):
    answer = []
    for i in range(n):
        answer.append(bin(arr1[i] | arr2[i])[2:].zfill(n).replace('1', '#').replace('0', ' '))
    return answer

# %%
solution(n, arr1, arr2)
# Out:
# ['#####', '# # #', '### #', '#  ##', '#####']

# %%
def solution(order):
    answer = 0
    order = str(order)
    answer += order.count('3')
    answer += order.count('6')
    answer += order.count('9')
    return answer

# %%
solution(29423)
# Out:
# 2

# %%
answer = 0
s = '36913699'
answer += s.count('3')
answer += s.count('6')
answer += s.count('9')
print(answer)
# Out:
# 7

# %%
s = str(list(range(101)))
s.count('3') + s.count('6') + s.count('9')
# Out:
# 60

# %%
table = str.maketrans("abc", "123")
'akbkckdkek'.translate(table)
# Out:
# '1k2k3kdkek'

# %%
# 'd'와 'e' 문자 제거하기
table = str.maketrans('', '', 'de')
text = "abcde"
result = text.translate(table)
print(result)  # abc
# Out:
# abc

# %%
import re

def solution(new_id):
    reform_id = new_id.lower()

    table1 = str.maketrans('', '', '~!@#$%^&*()=+[{]}:?,<>/')
    reform_id = reform_id.translate(table1)

    reform_id = re.sub('[.]+', '.', reform_id)

    if len(reform_id) != 0 and reform_id[-1] == '.':
        reform_id = reform_id[:-1]
    print(reform_id)

    if len(reform_id) != 0 and reform_id[0] == '.':
        reform_id = reform_id[1:]

    if len(reform_id) == 0:
        reform_id = 'a'

    reform_id = reform_id[:15]

    if len(reform_id) != 0 and reform_id[-1] == '.':
        reform_id = reform_id[:-1]

    if len(reform_id) <= 2:
        reform_id += (3 - len(reform_id)) * reform_id[-1]

    return reform_id

# %%
solution("abcdefghijklmn.p")
# Out:
# abcdefghijklmn.p
# 'abcdefghijklmn'

# %%
1단계 new_id의 모든 대문자를 대응되는 소문자로 치환합니다.
2단계 new_id에서 알파벳 소문자, 숫자, 빼기(-), 밑줄(_), 마침표(.)를 제외한 모든 문자를 제거합니다.
3단계 new_id에서 마침표(.)가 2번 이상 연속된 부분을 하나의 마침표(.)로 치환합니다.
4단계 new_id에서 마침표(.)가 처음이나 끝에 위치한다면 제거합니다.
5단계 new_id가 빈 문자열이라면, new_id에 "a"를 대입합니다.
6단계 new_id의 길이가 16자 이상이면, new_id의 첫 15개의 문자를 제외한 나머지 문자들을 모두 제거합니다.
     만약 제거 후 마침표(.)가 new_id의 끝에 위치한다면 끝에 위치한 마침표(.) 문자를 제거합니다.
7단계 new_id의 길이가 2자 이하라면, new_id의 마지막 문자를 new_id의 길이가 3이 될 때까지 반복해서 끝에 붙입니다.

# %%
# 문제 1
s = 'jun'
print(s + s[-1] * 2)

# 문제 2
s = 'Jun'
print(s.lower())

# 문제3
s = 'hello_world123'
table = str.maketrans("", "", "0123456789-_abcde")
s = s.translate(table)
print(s)
# Out:
# junnn
# jun
# hlloworl

# %%
x = True
dir(x)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
# ...

# %% [markdown]
# # None 자료형

# %%
# None은 수치 연산이 안된다.
# None + 5
# None + None
# None = 10
# sum([10, 20, None, 30, 40])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-912783361169> in <cell line: 4>()
#       2 # None + None
#       3 # None = 10
# ----> 4 sum([10, 20, None, 30, 40])
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %%
# None의 주소값은 유일하다.
x = None
y = None
print(id(x), id(y))
# Out:
# 102206551438304 102206551438304

# %%
x = None
print(x == None) # 중요! True지만 이 방식은 권장되지 않습니다.
print(x is None) # True, 이 방식을 사용하여 None을 확인하는 것이 좋음.
# Out:
# True
# True

# %%
class Character:

    def __init__(self, hp, mp):
        self.hp = hp
        self.mp = mp

    def __eq__(self, other):
        return True

주인공 = Character(100, 100)
print(주인공)

# %% [markdown]
# # 메서드 체이닝

# %%
sentence = "  Hello, World!  "
result = sentence.strip().lower().replace("world", "python")
# sentence.strip() => Hello, World!
# 'Hello, World!'.lower() => hello, world!
# 'hello, world!'.replace("world", "python") => hello, pytho!
print(result)  # "hello, python!"
# Out:
# hello, python!

# %%
# 백슬래쉬로
sentence = "  Hello, World!  "
result = sentence\
.strip()\
.lower()\
.replace("world", "python")

print(result)  # "hello, python!"
# Out:
# hello, python!

# %% [markdown]
# # 형 변환

# %%
월급 = input("월급을 입력하세요:")
연봉 = 월급 * 12
print(연봉)
# Out:
# 월급을 입력하세요:100
# 100100100100100100100100100100100100

# %%
월급 = int(input("월급을 입력하세요:"))
연봉 = 월급 * 12
print(연봉)
# Out:
# 월급을 입력하세요:100
# 1200

# %%
# 자주 사용하는 문법
list(map(int, ['10', '20', '30']))
# Out:
# [10, 20, 30]

# %%
true_int = int(True)
false_int = int(False)

print(true_int)  # 출력: 1
print(false_int)  # 출력: 0
# Out:
# 1
# 0

# %%
n = 123
print(type(n))

m = 123.4
print(type(n))

n = str(n)
print(type(n))

m = str(m)
print(type(m))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'str'>

# %%
# 이 경우는 에러 m이 '123.4'인 문자열의 경우 -> 자주하는 실
m = int(m)
print(type(m))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-c055973c09f3> in <cell line: 1>()
# ----> 1 m = int(m)
#       2 print(type(m))
#
# ValueError: invalid literal for int() with base 10: '123.4'

# %%
print("bool('test'):", bool('test'))
print("bool(' '):", bool(' '))
print("bool(''):", bool(''))
print("bool(100):", bool(100))
print("bool(1):", bool(1))
print("bool(0):", bool(0))
print("bool(-1):", bool(-1))
print("bool(None):", bool(None))
print("bool([]):", bool([])) # 주의 - JavaScript에서는 true, Python에서는 False
print("bool(tuple()):", bool(tuple()))
print("bool({}):", bool({}))
print("bool(set()):", bool(set()))
# Out:
# bool('test'): True
# bool(' '): True
# bool(''): False
# bool(100): True
# bool(1): True
# bool(0): False
# bool(-1): True
# bool(None): False
# bool([]): False
# bool(tuple()): False
# bool({}): False
# bool(set()): False

# %%
# 실무에서 많이 사용하는 코드
x = [1, 2, 3]
while x:
    print(x.pop())
# Out:
# 3
# 2
# 1

# %%
s = '30'
print(list(s))

name = 'ruler'
print(list(name))
# Out:
# ['3', '0']
# ['r', 'u', 'l', 'e', 'r']

# %%
s = 'ormi THIRD ruler'
print(set(s)) #중복을 허락하지 않고 순서가 없습니다.
print(len(set(s))) #중복을 제거한 상태로의 길이를 알려줍니다.
print(len(s))
# Out:
# {'T', 'R', 'i', 'm', ' ', 'D', 'I', 'o', 'H', 'u', 'r', 'e', 'l'}
# 13
# 16

# %% [markdown]
# # 연습문제

# %%
# 항상 확장자만 나오게 하는 코드
s = 'li.cat.jpeg'
s.split('.')[-1]
# Out:
# 'jpeg'

# %%
s.split('.')[-1]
# Out:
# 'jpeg'
